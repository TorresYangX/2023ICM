# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\Sakura Yang\Desktop\MCM\data\result.xlsx")

# %%
data
# Out:
#    Unnamed: 0  No Poverty  Zero Hunger  Good Health and Well-being  \
# 0        2000    0.332567     0.253505                    0.224200
# 1        2005    0.252613     0.248431                    0.209989
# 2        2010    0.204183     0.200515                    0.200287
# 3        2015    0.149767     0.186663                    0.187796
# 4        2020    0.060869     0.192788                    0.177729
#
#    Quality Education  Gender Equality  Clean Water and Sanitation  \
# 0           0.379445         0.326213                    0.367339
# 1           0.293376         0.268280                    0.303011
# 2           0.132718         0.207207                    0.246064
# 3           0.114027         0.140446                    0.078317
# 4           0.080434         0.057854                    0.005270
#
#    Affordable and Clean Energy  Decent Work and Economic Growth  \
# 0                     0.314773                         0.134969
# ...

# %%
data1 = data

# %%
data2 = data1.set_index('Unnamed: 0',drop=False)

# %%
data2.index.name = None

# %%
data2=data2.drop('Unnamed: 0',axis=1)

# %%
data2
# Out:
#       No Poverty  Zero Hunger  Good Health and Well-being  Quality Education  \
# 2000    0.332567     0.253505                    0.224200           0.379445
# 2005    0.252613     0.248431                    0.209989           0.293376
# 2010    0.204183     0.200515                    0.200287           0.132718
# 2015    0.149767     0.186663                    0.187796           0.114027
# 2020    0.060869     0.192788                    0.177729           0.080434
#
#       Gender Equality  Clean Water and Sanitation  \
# 2000         0.326213                    0.367339
# 2005         0.268280                    0.303011
# 2010         0.207207                    0.246064
# 2015         0.140446                    0.078317
# 2020         0.057854                    0.005270
#
#       Affordable and Clean Energy  Decent Work and Economic Growth  \
# 2000                     0.314773                         0.134969
# ...

# %%
corr = data2.corr()

# %%
corr
# Out:
#                                          No Poverty  Zero Hunger  \
# No Poverty                                 1.000000     0.860251
# Zero Hunger                                0.860251     1.000000
# Good Health and Well-being                 0.993326     0.900387
# Quality Education                          0.927176     0.970658
# Gender Equality                            0.995796     0.881106
# Clean Water and Sanitation                 0.970865     0.868432
# Affordable and Clean Energy                0.974250     0.893567
# Decent Work and Economic Growth           -0.695187    -0.303555
# Industry, Innovation and Infrastructure    0.924810     0.932957
# Reduced Inequality                         0.722734     0.499858
# Sustainable Cities and Communities         0.948801     0.921655
# Responsible Consumption and Production     0.962130     0.773086
# Climate Action                             0.891375     0.901695
# ...

# %%
corr = corr.abs()

# %%
fig = plt.figure(figsize=(15,15))
fig = sns.heatmap(corr,vmax=1,vmin=0,linewidths=0.05,linecolor='black')
fig.set_title('Correlation heatmap',fontsize=25)
plt.tick_params(labelsize=15,rotation=25)
plt.show()
ax = fig.get_figure()
ax.savefig('heatmap.jpg',dpi=500,bbox_inches='tight')
# plt.title('Correlation heatmap',fontsize=25)

# %%
corr
# Out:
#                                          No Poverty  Zero Hunger  \
# No Poverty                                 1.000000     0.860251
# Zero Hunger                                0.860251     1.000000
# Good Health and Well-being                 0.993326     0.900387
# Quality Education                          0.927176     0.970658
# Gender Equality                            0.995796     0.881106
# Clean Water and Sanitation                 0.970865     0.868432
# Affordable and Clean Energy                0.974250     0.893567
# Decent Work and Economic Growth            0.695187     0.303555
# Industry, Innovation and Infrastructure    0.924810     0.932957
# Reduced Inequality                         0.722734     0.499858
# Sustainable Cities and Communities         0.948801     0.921655
# Responsible Consumption and Production     0.962130     0.773086
# Climate Action                             0.891375     0.901695
# ...

# %%
dirt_C = {'No Poverty':'SDG1','Zero Hunger':'SDG2','Good Health and Well-being':'SDG3'}

# %%
dirt_C2={'Quality Education':'SDG4','Gender Equality':'SDG5','Clean Water and Sanitation':'SDG6','Affordable and Clean Energy':'SDG7','Decent Work and Economic Growth':'SDG8','Industry, Innovation and Infrastructure':'SDG9'}

# %%
dirt_C3={'Reduced Inequality':'SDG10','Sustainable Cities and Communities':'SDG11','Responsible Consumption and Production':'SDG12','Climate Action':'SDG13','Life Below Water':'SDG14','Life on Land':'SDG15','Peace and Justice Strong Institutions':'SDG16','Partnerships to achieve the Goal':'SDG17'}

# %%
corr=corr.rename(columns=dirt_C)

# %%
corr=corr.rename(columns=dirt_C2)

# %%
corr=corr.rename(columns=dirt_C3)

# %%
corr=corr.rename(index=dirt_C)

# %%
corr=corr.rename(index=dirt_C2)

# %%
corr=corr.rename(index=dirt_C3)

# %%
corr
# Out:
#            SDG1      SDG2      SDG3      SDG4      SDG5      SDG6      SDG7  \
# SDG1   1.000000  0.860251  0.993326  0.927176  0.995796  0.970865  0.974250
# SDG2   0.860251  1.000000  0.900387  0.970658  0.881106  0.868432  0.893567
# SDG3   0.993326  0.900387  1.000000  0.948921  0.992918  0.978712  0.974461
# SDG4   0.927176  0.970658  0.948921  1.000000  0.927854  0.887398  0.911987
# SDG5   0.995796  0.881106  0.992918  0.927854  1.000000  0.984435  0.990674
# SDG6   0.970865  0.868432  0.978712  0.887398  0.984435  1.000000  0.986250
# SDG7   0.974250  0.893567  0.974461  0.911987  0.990674  0.986250  1.000000
# SDG8   0.695187  0.303555  0.614766  0.418377  0.688220  0.652689  0.681064
# SDG9   0.924810  0.932957  0.942885  0.907448  0.954706  0.968760  0.982095
# SDG10  0.722734  0.499858  0.659424  0.546118  0.742991  0.704918  0.776593
# SDG11  0.948801  0.921655  0.972233  0.916220  0.967687  0.988894  0.975367
# ...

# %%
corr.to_excel('corr.xlsx')

# %%
links = corr.stack().reset_index()

# %%
links
# Out:
#     level_0 level_1         0
# 0      SDG1    SDG1  1.000000
# 1      SDG1    SDG2  0.860251
# 2      SDG1    SDG3  0.993326
# 3      SDG1    SDG4  0.927176
# 4      SDG1    SDG5  0.995796
# ..      ...     ...       ...
# 284   SDG17   SDG13  0.836862
# 285   SDG17   SDG14  0.876053
# 286   SDG17   SDG15  0.727579
# 287   SDG17   SDG16  0.583754
# 288   SDG17   SDG17  1.000000
#
# [289 rows x 3 columns]

# %%
links.columns = ['var1', 'var2','value']

# %%
links
# Out:
#       var1   var2     value
# 0     SDG1   SDG1  1.000000
# 1     SDG1   SDG2  0.860251
# 2     SDG1   SDG3  0.993326
# 3     SDG1   SDG4  0.927176
# 4     SDG1   SDG5  0.995796
# ..     ...    ...       ...
# 284  SDG17  SDG13  0.836862
# 285  SDG17  SDG14  0.876053
# 286  SDG17  SDG15  0.727579
# 287  SDG17  SDG16  0.583754
# 288  SDG17  SDG17  1.000000
#
# [289 rows x 3 columns]

# %%
links_filtered=links.loc[ (links['value'] <= 0.8) & (links['var1'] != links['var2']) ]#剔除相同编号的行以及相关系数小于0.8的行

# %%
links_filtered
# Out:
#       var1   var2     value
# 7     SDG1   SDG8  0.695187
# 9     SDG1  SDG10  0.722734
# 15    SDG1  SDG16  0.577160
# 16    SDG1  SDG17  0.773684
# 24    SDG2   SDG8  0.303555
# ..     ...    ...       ...
# 281  SDG17  SDG10  0.748992
# 282  SDG17  SDG11  0.737283
# 283  SDG17  SDG12  0.741213
# 286  SDG17  SDG15  0.727579
# 287  SDG17  SDG16  0.583754
#
# [110 rows x 3 columns]

# %%
plt.figure(figsize=(20,20))

# %%
G=nx.from_pandas_edgelist(links_filtered, 'var1', 'var2')

# %%
weight=pd.read_excel("weight.xlsx")

# %%
weight
# Out:
#                                        name  value  influence
# 0                                No Poverty   6.28  89.620610
# 1                               Zero Hunger   7.50  82.804523
# 2                Good Health and Well-being   5.66  89.494331
# 3                         Quality Education   7.31  85.488438
# 4                           Gender Equality   7.03  90.679335
# 5                Clean Water and Sanitation   4.94  89.021341
# 6               Affordable and Clean Energy   7.22  90.937026
# 7           Decent Work and Economic Growth   5.27  61.238982
# 8   Industry, Innovation and Infrastructure   6.51  88.809068
# 9                        Reduced Inequality   2.38  70.205533
# 10       Sustainable Cities and Communities   6.25  88.172332
# 11   Responsible Consumption and Production   7.20  88.078638
# 12                           Climate Action   5.61  87.291140
# 13                         Life Below Water   6.21  80.677349
# ...

# %%
influence=[]

# %%
for i in range(len(weight)):
    row='SDG'+str((i+1))
    x = 0.0
    for j in range(len(weight)):
        col='SDG'+str(j+1)
        x+=corr[row][col]*weight.loc[j]['value']
    influence.append(x)

# %%
influence
# Out:
# [89.62060970438678,
#  82.80452325742635,
#  89.49433053850136,
#  85.48843806878247,
#  90.67933525527985,
#  89.02134094808589,
#  90.93702639380548,
#  61.23898190435578,
#  88.80906794765689,
#  70.205532568374,
#  88.17233215720819,
#  88.07863833771106,
#  87.29113975940419,
#  80.6773490491224,
#  82.6740153635426,
#  56.6811975892699,
#  77.66776010276637]

# %%
nx.draw_circular(G, with_labels=True, node_color=['r','goldenrod','limegreen','brown','lightcoral','c','gold','maroon','coral','m','orange','darkgoldenrod','darkgreen','steelblue','olivedrab','lavender','royalblue'], node_size=[v * 15for v in influence], edge_color='black', linewidths=7, font_size=10)

# %%
weight['influence']=influence

# %%
weight
# Out:
#                                        name  value  influence
# 0                                No Poverty   6.28  89.620610
# 1                               Zero Hunger   7.50  82.804523
# 2                Good Health and Well-being   5.66  89.494331
# 3                         Quality Education   7.31  85.488438
# 4                           Gender Equality   7.03  90.679335
# 5                Clean Water and Sanitation   4.94  89.021341
# 6               Affordable and Clean Energy   7.22  90.937026
# 7           Decent Work and Economic Growth   5.27  61.238982
# 8   Industry, Innovation and Infrastructure   6.51  88.809068
# 9                        Reduced Inequality   2.38  70.205533
# 10       Sustainable Cities and Communities   6.25  88.172332
# 11   Responsible Consumption and Production   7.20  88.078638
# 12                           Climate Action   5.61  87.291140
# 13                         Life Below Water   6.21  80.677349
# ...

# %%
weight.to_excel('weight.xlsx')

# %%
data2
# Out:
#       No Poverty  Zero Hunger  Good Health and Well-being  Quality Education  \
# 2000    0.332567     0.253505                    0.224200           0.379445
# 2005    0.252613     0.248431                    0.209989           0.293376
# 2010    0.204183     0.200515                    0.200287           0.132718
# 2015    0.149767     0.186663                    0.187796           0.114027
# 2020    0.060869     0.192788                    0.177729           0.080434
#
#       Gender Equality  Clean Water and Sanitation  \
# 2000         0.326213                    0.367339
# 2005         0.268280                    0.303011
# 2010         0.207207                    0.246064
# 2015         0.140446                    0.078317
# 2020         0.057854                    0.005270
#
#       Affordable and Clean Energy  Decent Work and Economic Growth  \
# 2000                     0.314773                         0.134969
# ...

# %%
est_1=data2.rename(columns=dirt_C)
est_1=est_1.rename(columns=dirt_C2)
est_1=est_1.rename(columns=dirt_C3)

# %%
est_1
# Out:
#           SDG1      SDG2      SDG3      SDG4      SDG5      SDG6      SDG7  \
# 2000  0.332567  0.253505  0.224200  0.379445  0.326213  0.367339  0.314773
# 2005  0.252613  0.248431  0.209989  0.293376  0.268280  0.303011  0.294878
# 2010  0.204183  0.200515  0.200287  0.132718  0.207207  0.246064  0.210834
# 2015  0.149767  0.186663  0.187796  0.114027  0.140446  0.078317  0.129705
# 2020  0.060869  0.192788  0.177729  0.080434  0.057854  0.005270  0.049810
#
#           SDG8      SDG9     SDG10     SDG11     SDG12     SDG13     SDG14  \
# 2000  0.134969  0.285308  0.218086  0.225597  0.235015  0.207079  0.235602
# 2005  0.151628  0.297078  0.284252  0.217643  0.225239  0.211346  0.214660
# 2010  0.090962  0.204798  0.220164  0.203905  0.213896  0.200853  0.183246
# 2015  0.107021  0.119898  0.230925  0.177874  0.184058  0.192321  0.204188
# 2020  0.515411  0.092908  0.046582  0.174982  0.141791  0.188401  0.162304
#
#          SDG15     SDG16     SDG17
# ...

# %%
corr1=corr.rename(columns=dirt_C)
corr1=corr1.rename(columns=dirt_C2)
corr1=corr1.rename(columns=dirt_C3)
corr1=corr1.rename(index=dirt_C)
corr1=corr1.rename(index=dirt_C2)
corr1=corr1.rename(index=dirt_C3)

# %%
corr1
# Out:
#            SDG1      SDG2      SDG3      SDG4      SDG5      SDG6      SDG7  \
# SDG1   1.000000  0.860251  0.993326  0.927176  0.995796  0.970865  0.974250
# SDG2   0.860251  1.000000  0.900387  0.970658  0.881106  0.868432  0.893567
# SDG3   0.993326  0.900387  1.000000  0.948921  0.992918  0.978712  0.974461
# SDG4   0.927176  0.970658  0.948921  1.000000  0.927854  0.887398  0.911987
# SDG5   0.995796  0.881106  0.992918  0.927854  1.000000  0.984435  0.990674
# SDG6   0.970865  0.868432  0.978712  0.887398  0.984435  1.000000  0.986250
# SDG7   0.974250  0.893567  0.974461  0.911987  0.990674  0.986250  1.000000
# SDG8   0.695187  0.303555  0.614766  0.418377  0.688220  0.652689  0.681064
# SDG9   0.924810  0.932957  0.942885  0.907448  0.954706  0.968760  0.982095
# SDG10  0.722734  0.499858  0.659424  0.546118  0.742991  0.704918  0.776593
# SDG11  0.948801  0.921655  0.972233  0.916220  0.967687  0.988894  0.975367
# ...

# %%
temp=[]

# %%
x = est_1.loc[2020]['SDG1']
for i in range(1,18):
    if i==1:
        temp.append(0)
    if i!=1:
        s = 'SDG'+str(i)
        a = est_1.loc[2020][s]
        wet = corr1.loc['SDG1'][s]
        b=a-x*wet
        temp.append(b)

# %%
temp
# Out:
# [0,
#  0.140424899427195,
#  0.11726557053196013,
#  0.023997572529269935,
#  -0.0027590839044477275,
#  -0.05382557720645538,
#  -0.00949204199347553,
#  0.47309502933651976,
#  0.036615890982351434,
#  0.0025897599636980004,
#  0.11722905271863467,
#  0.08322639607160454,
#  0.1341433924119531,
#  0.1075795349762999,
#  0.020736265137204564,
#  0.16100324961982299,
#  0.14751976717719742]

# %%
est_1=est_1.drop(5)

# %%
est_1.loc[len(est_1.index)] = temp

# %%
est_1
# Out:
#           SDG1      SDG2      SDG3      SDG4      SDG5      SDG6      SDG7  \
# 2000  0.332567  0.253505  0.224200  0.379445  0.326213  0.367339  0.314773
# 2005  0.252613  0.248431  0.209989  0.293376  0.268280  0.303011  0.294878
# 2010  0.204183  0.200515  0.200287  0.132718  0.207207  0.246064  0.210834
# 2015  0.149767  0.186663  0.187796  0.114027  0.140446  0.078317  0.129705
# 2020  0.060869  0.192788  0.177729  0.080434  0.057854  0.005270  0.049810
# 5     0.000000  0.140425  0.117266  0.023998 -0.002759 -0.053826 -0.009492
#
#           SDG8      SDG9     SDG10     SDG11     SDG12     SDG13     SDG14  \
# 2000  0.134969  0.285308  0.218086  0.225597  0.235015  0.207079  0.235602
# 2005  0.151628  0.297078  0.284252  0.217643  0.225239  0.211346  0.214660
# 2010  0.090962  0.204798  0.220164  0.203905  0.213896  0.200853  0.183246
# 2015  0.107021  0.119898  0.230925  0.177874  0.184058  0.192321  0.204188
# ...

# %%
est_2=est_1.drop('SDG1',axis=1)

# %%
cor=est_2.corr()

# %%
cor
# Out:
#            SDG2      SDG3      SDG4      SDG5      SDG6      SDG7      SDG8  \
# SDG2   1.000000  0.927262  0.946780  0.933950  0.913290  0.938373 -0.590280
# SDG3   0.927262  1.000000  0.825270  0.918707  0.883133  0.907762 -0.735693
# SDG4   0.946780  0.825270  1.000000  0.940235  0.919367  0.931446 -0.593610
# SDG5   0.933950  0.918707  0.940235  1.000000  0.988073  0.994605 -0.802170
# SDG6   0.913290  0.883133  0.919367  0.988073  1.000000  0.989879 -0.772620
# SDG7   0.938373  0.907762  0.931446  0.994605  0.989879  1.000000 -0.796938
# SDG8  -0.590280 -0.735693 -0.593610 -0.802170 -0.772620 -0.796938  1.000000
# SDG9   0.953355  0.883186  0.931353  0.972438  0.980204  0.988855 -0.717059
# SDG10  0.759644  0.840024  0.700882  0.861462  0.824397  0.877152 -0.937160
# SDG11  0.952409  0.989235  0.854275  0.941222  0.925051  0.940371 -0.719421
# SDG12  0.902705  0.971688  0.832745  0.960790  0.939480  0.959008 -0.854069
# ...

# %%
cor1=cor.abs()

# %%
fig = plt.figure(figsize=(15,15))
fig = sns.heatmap(cor1,vmax=1,vmin=0,linewidths=0.05,linecolor='black')
fig.set_title('Correlation heatmap',fontsize=25)
plt.tick_params(labelsize=15,rotation=25)
plt.show()
ax = fig.get_figure()
ax.savefig('est_17_heatmap.jpg',dpi=500,bbox_inches='tight')
# plt.title('Correlation heatmap',fontsize=25)

# %%
links = cor1.stack().reset_index()
links.columns = ['var1', 'var2','value']
links
# Out:
#       var1   var2     value
# 0     SDG1   SDG1  1.000000
# 1     SDG1   SDG2  0.923646
# 2     SDG1   SDG3  0.907538
# 3     SDG1   SDG4  0.961225
# 4     SDG1   SDG5  0.998416
# ..     ...    ...       ...
# 251  SDG16  SDG12  0.937021
# 252  SDG16  SDG13  0.995074
# 253  SDG16  SDG14  0.964517
# 254  SDG16  SDG15  0.587610
# 255  SDG16  SDG16  1.000000
#
# [256 rows x 3 columns]

# %%
links_filtered=links.loc[ (links['value'] > 0.8) & (links['var1'] != links['var2']) ]#剔除相同编号的行以及相关系数小于0.8的行

# %%
G1=nx.from_pandas_edgelist(links_filtered, 'var1', 'var2')

# %%
inf=[]

# %%
for i in range(1,18):
    if i!=1:
        row='SDG'+str(i)
        x = 0.0
        for j in range(1,18):
            if j!=1:
                col='SDG'+str(j)
                x+=cor1[row][col]*weight.loc[j-1]['value']
        inf.append(x)

# %%
inf
# Out:
# [83.44572527816125,
#  84.1685152244304,
#  79.2148687036979,
#  85.22482157363149,
#  83.2370589693968,
#  85.08980830652585,
#  67.74046983857261,
#  83.64426639822351,
#  76.52614733918222,
#  85.22544740204668,
#  85.33736317766851,
#  80.247781200232,
#  82.70737750405256,
#  74.28808287735906,
#  71.189553584633,
#  75.40276726336515]

# %%
ts=pd.read_excel('test.xlsx')

# %%
ts['SDG1']=inf

# %%
ts
# Out:
#      x       SDG1       SDG2       SDG3       SDG4       SDG5       SDG6  \
# 0    1  83.445725  85.417115  87.147972  84.255949  84.077585  87.156237
# 1    2  84.168515  83.288054  86.055273  83.433108  82.603944  80.582403
# 2    3  79.214869  81.631726  82.656520  83.852318  83.614716  87.256448
# 3    4  85.224822  85.599219  87.284388  84.557386  78.462750  83.099119
# 4    5  83.237059  83.140582  84.939513  82.321198  82.472336  87.843311
# 5    6  85.089808  85.374856  86.991088  84.363522  84.300409  87.967471
# 6    7  67.740470  65.564497  61.125191  69.038173  67.325734  68.460257
# 7    8  83.644266  85.063693  86.449213  83.056014  82.843808  86.224832
# 8    9  76.526147  79.492038  81.464643  77.026386  75.730782  74.273216
# 9   10  85.225447  83.984807  85.348401  84.863252  84.478192  86.130306
# 10  11  85.337363  85.926363  86.917195  85.672201  84.563124  85.824859
# 11  12  80.247781  80.751108  82.084065  80.321775  79.410323  85.600054
# ...

# %%
ts.to_excel('test.xlsx')

# %%
nx.draw_circular(G1, with_labels=True, node_color=['goldenrod','limegreen','brown','lightcoral','c','gold','maroon','coral','m','orange','darkgoldenrod','darkgreen','steelblue','olivedrab','lavender','royalblue'], node_size=[v * 15for v in inf], edge_color='black', linewidths=7, font_size=10)

# %%
linear=pd.read_excel('linear.xlsx')

# %%
linear
# Out:
#                                        name   const      k
# 0                                No Poverty  26.179 -0.013
# 1                               Zero Hunger   7.581 -0.004
# 2                Good Health and Well-being   4.828 -0.002
# 3                         Quality Education  31.450 -0.016
# 4                           Gender Equality  26.915 -0.013
# 5                Clean Water and Sanitation  38.343 -0.019
# 6               Affordable and Clean Energy  28.143 -0.014
# 7           Decent Work and Economic Growth -28.594  0.014
# 8   Industry, Innovation and Infrastructure  22.792 -0.011
# 9                        Reduced Inequality  16.133 -0.008
# 10       Sustainable Cities and Communities   5.868 -0.003
# 11   Responsible Consumption and Production   9.351 -0.005
# 12                           Climate Action   2.467 -0.001
# 13                         Life Below Water   6.514 -0.003
# 14                             Life on Land  40.714 -0.020
# ...

# %%
weight
# Out:
#                                        name  value  influence
# 0                                No Poverty   6.28  89.620610
# 1                               Zero Hunger   7.50  82.804523
# 2                Good Health and Well-being   5.66  89.494331
# 3                         Quality Education   7.31  85.488438
# 4                           Gender Equality   7.03  90.679335
# 5                Clean Water and Sanitation   4.94  89.021341
# 6               Affordable and Clean Energy   7.22  90.937026
# 7           Decent Work and Economic Growth   5.27  61.238982
# 8   Industry, Innovation and Infrastructure   6.51  88.809068
# 9                        Reduced Inequality   2.38  70.205533
# 10       Sustainable Cities and Communities   6.25  88.172332
# 11   Responsible Consumption and Production   7.20  88.078638
# 12                           Climate Action   5.61  87.291140
# 13                         Life Below Water   6.21  80.677349
# ...

# %%
weight_1=pd.read_excel('weight_1.xlsx')
weight_1
# Out:
#     Unnamed: 0                                     name   value
# 0            0                               No Poverty  6.1885
# 1            1                              Zero Hunger  7.4085
# 2            2               Good Health and Well-being  5.5685
# 3            3                        Quality Education  7.2185
# 4            4                          Gender Equality  6.9385
# 5            5               Clean Water and Sanitation  4.8485
# 6            6              Affordable and Clean Energy  8.6440
# 7            7          Decent Work and Economic Growth  5.1785
# 8            8  Industry, Innovation and Infrastructure  6.4185
# 9            9                       Reduced Inequality  2.2885
# 10          10       Sustainable Cities and Communities  6.1585
# 11          11   Responsible Consumption and Production  7.1085
# 12          12                           Climate Action  5.5185
# 13          13                         Life Below Water  6.1185
# ...

# %%
tmp=[]
for i in range(2023,2033):
    temp=[]
    y=0
    for j in range(17):
        x=linear.loc[j]['const']+linear.loc[j]['k']*i
        temp.append(x)
    for j in range(17):
        y+=temp[j]*weight_1.loc[j]['value']
    tmp.append(y)

# %%
tmp
# Out:
# [4.381100000000003,
#  3.628570000000024,
#  2.8760400000000326,
#  2.1235099999999854,
#  1.370980000000027,
#  0.618450000000041,
#  -0.1340799999999538,
#  -0.8866099999999966,
#  -1.6391399999999567,
#  -2.3916699999999906]

# %%
predict = pd.read_excel('predict.xlsx')

# %%
predict['initial']=tmp

# %%
predict['boost']=tmp

# %%
predict
# Out:
#    Unnamed: 0  initial  boost     boost
# 0        2023  4.80582     NaN  4.38110
# 1        2024  4.06371     NaN  3.62857
# 2        2025  3.32160     NaN  2.87604
# 3        2026  2.57949     NaN  2.12351
# 4        2027  1.83738     NaN  1.37098
# 5        2028  1.09527     NaN  0.61845
# 6        2029  0.35316     NaN -0.13408
# 7        2030 -0.38895     NaN -0.88661
# 8        2031 -1.13106     NaN -1.63914
# 9        2032 -1.87317     NaN -2.39167

# %%
predict.to_excel('predict.xlsx')

# %%
data2
# Out:
#       No Poverty  Zero Hunger  Good Health and Well-being  Quality Education  \
# 2000    0.332567     0.253505                    0.224200           0.379445
# 2005    0.252613     0.248431                    0.209989           0.293376
# 2010    0.204183     0.200515                    0.200287           0.132718
# 2015    0.149767     0.186663                    0.187796           0.114027
# 2020    0.060869     0.192788                    0.177729           0.080434
#
#       Gender Equality  Clean Water and Sanitation  \
# 2000         0.326213                    0.367339
# 2005         0.268280                    0.303011
# 2010         0.207207                    0.246064
# 2015         0.140446                    0.078317
# 2020         0.057854                    0.005270
#
#       Affordable and Clean Energy  Decent Work and Economic Growth  \
# 2000                     0.314773                         0.134969
# ...

# %%
x=[2000,2005,2010,2015,2020]

# %%
plt.figure(figsize=(15,15))

# %%
x2=np.linspace(2000,2020,25)

# %%
y=-0.019*x2+38.383

# %%
plt.plot(x2,y)
plt.scatter(x,data2['Clean Water and Sanitation'],c='red')
plt.xticks(x)
# Out:
# ([<matplotlib.axis.XTick at 0x1b5bd8f6ee0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.savefig('linear example.jpg',dpi=500)

# %%
fig=plt.figure(figsize=(20,20))
x2=np.linspace(2000,2020,50)
for i in range (17):
    y = linear.loc[i]['const']+linear.loc[i]['k']*x2
    plt.plot(x2,y,linewidth =4.0,label=linear.loc[i]['name'])
plt.rcParams.update({'font.size': 20})
plt.legend(labelspacing=2,bbox_to_anchor=(0, 1),)

# %%
ax2=fig.get_figure()

# %%
ax2.savefig('lines.jpg',dpi=500,bbox_inches='tight')

# %%
pre = pd.read_excel('predict_1.xlsx')
pre
# Out:
#    year  initial  initiate priority  Unnamed: 3
# 0  2023  4.80582            4.38110     0.42472
# 1  2024  4.06371            3.62857     0.43514
# 2  2025  3.32160            2.87604     0.44556
# 3  2026  2.57949            2.12351     0.45598
# 4  2027  1.83738            1.37098     0.46640
# 5  2028  1.09527            0.61845     0.47682
# 6  2029  0.35316           -0.13408     0.48724
# 7  2030 -0.38895           -0.88661     0.49766
# 8  2031 -1.13106           -1.63914     0.50808
# 9  2032 -1.87317           -2.39167     0.51850

# %%
x=[]
for i in range(10):
    x.append(pre.loc[i]['year'])
x=list(map(int, x))
x
# Out:
# [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]

# %%
y=[]
for i in range(10):
    y.append(pre.loc[i]['Unnamed: 3'])
y
# Out:
# [0.42472,
#  0.43514000000001,
#  0.44556,
#  0.45598000000001,
#  0.4664,
#  0.476819999999999,
#  0.487240000000001,
#  0.497660000000003,
#  0.50808,
#  0.5185]

# %%
z=[]
for i in range(10):
    asd=pre.loc[0]['initial']-pre.loc[i]['initial']
    z.append(asd)
z
# Out:
# [0.0,
#  0.7421099999999701,
#  1.48421999999997,
#  2.2263300000000097,
#  2.96843999999997,
#  3.7105499999999596,
#  4.452659999999953,
#  5.194769999999994,
#  5.9368799999999595,
#  6.67898999999999]

# %%
m=[]
for i in range(10):
    asd=pre.loc[0]['initiate priority']-pre.loc[i]['initiate priority']
    m.append(asd)
m
# Out:
# [0.0,
#  0.7525299999999802,
#  1.50505999999997,
#  2.25759000000002,
#  3.01011999999997,
#  3.762649999999959,
#  4.515179999999954,
#  5.2677099999999975,
#  6.02023999999996,
#  6.772769999999991]

# %%
fig2=plt.figure(figsize=(15, 15))
plt.xticks(x)
plt.plot(x, z, '*--', linewidth=5, label='initial')
plt.plot(x, m, 'r', linewidth=5, label='initiate priority')
#plt.plot(x, y, 'y', linewidth=5, label='initiate priority')
plt.tick_params(labelsize=30)
plt.rcParams.update({'font.size': 40})
plt.legend()

# %%
ax1=fig2.get_figure()
ax1.savefig('pre_1.jpg',dpi=500,bbox_inches='tight')

# %%
fig3=plt.figure(figsize=(15, 15))
plt.xticks(x)
plt.plot(x, y, 'y', linewidth=5)
plt.tick_params(labelsize=30)
# plt.rcParams.update({'font.size': 20})
# plt.legend()

# %%
ax0=fig3.get_figure()
ax0.savefig('pre_2.jpg',dpi=500,bbox_inches='tight')
